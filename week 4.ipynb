# %%
-#condition equal
a = 5
a == 6
# Out:
# False

# %%
#Greater than sign
i = 6
i > 1
# Out:
# True

# %%
#false
i = 2
i > 5
# Out:
# False

# %%
# Inequality Sign
i = 2
i != 3
# Out:
# True

# %%
# Inequality Sign
i = 6
i != 6
# Out:
# False

# %%
"ACDC" == "Michael Jackson"
# Out:
# False

# %%
"ACDC" != "Michael Jackson"
# Out:
# True

# %%
'B' > 'A'
# Out:
# True

# %%
'BA' > 'AB'
# Out:
# True

# %%
"ba" >= 'ba'
# Out:
# True

# %%
#nyoba if

#usia
usia = 18
if usia > 18:
   print("kamu bisa masuk")
print('move on')
# Out:
# move on

# %%
usia = 20
if usia > 18:
  print('kamu bisa masuk')
else:
  print('kamu tidak bisa masuk')

print('move on')
# Out:
# kamu bisa masuk
# move on

# %%
usia = 18
if usia > 18:
  print('KAMU BISA MASUK')
elif usia == 18:
  print('bole lah, bolee lah')
else:
  print('sayang sekali')

print("hati hati dijalan")
# Out:
# bole lah, bolee lah
# hati hati dijalan

# %%
album_year = 1983
if album_year > 1980:
  print('Album year is greater than 1980')

print('do something...')
# Out:
# Album year is greater than 1980
# do something...

# %%
album_year = 1970
if album_year > 1980:
  print('Album year is greater than 1980')
else:
  print('less than 1980')

print('do something...')
# Out:
# less than 1980
# do something...

# %%
album_year = 1980
if(album_year > 1960) and (album_year < 1990):
  print('Album year was in between 1971 and 1989')
print('')
print('do stuff...')
# Out:
# Album year was in between 1971 and 1989
#
# do stuff...

# %%
album_year = 1980
if(album_year < 1980) or (album_year > 1980):
  print("album tida dibuat pada tahun 80an")
else:
  print('album dibuat pada tahun 80an')
# Out:
# album dibuat pada tahun 80an

# %%
#weakly 1

umur = int(input("masukkan umur anda: "))
if umur >= 17:
  print('boleh membuat sim')
else:
  print('tidak boleh buat sim')
# Out:
# masukkan umur anda: 16
# tidak boleh buat sim

# %%
#weeakly 2
nilai = int(input('masukkan nilai anda: '))
if nilai >= 90:
  print('A')
elif nilai >= 80:
  print('B+')
elif nilai >= 70:
  print('B')
elif nilai >= 60:
  print('C')
elif nilai >=50:
  print('C')
elif nilai >= 40:
  print('D')
else:
  print('E')
# Out:
# masukkan nilai anda: 83
# B+

# %%
#weeakly 3
nilai = float(input('masukkan nilai anda: '))
if nilai >= 80.00:
  print('A')
elif nilai >= 77.50:
  print('A-')
elif nilai >= 75.00:
  print('A/B')
elif nilai >= 72.50:
  print('B+')
elif nilai >= 70.00:
  print('B')
elif nilai >= 67.50:
  print('B-')
elif nilai >= 65.00:
  print("B/C")
elif nilai >= 62.50:
  print('C+')
elif nilai >= 60.00:
  print('C')
elif nilai >= 55.00:
  print('C-')
elif nilai >= 50.00:
  print('C/D')
elif nilai >= 45.00:
  print('D+')
elif nilai >= 40.00:
  print('D')
else:
  print('E')
# Out:
# masukkan nilai anda: 73
# B+
