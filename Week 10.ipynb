# %%
def my_function():
  print("Hello from a function")
my_function()
# Out:
# Hello from a function

# %%
def my_function(fname):
  print(fname + "Sitohang")
my_function('toha')
my_function('tohir')
my_function('tobi')
# Out:
# tohaSitohang
# tohirSitohang
# tobiSitohang

# %%
def my_function(fname, lname):
  print(fname + " " + lname)
my_function('toha', 'sitohang')
# Out:
# toha sitohang

# %%
def faktorial(x):
  if x < 0:
    return
  elif x == 0:
    return 1
  else:
    product = 1
    for i in range(x):
      product = product * (i+1)
    return product
faktorial(int(input('Faktorial dari angka : ')))
# Out:
# Faktorial dari angka : 10
# 3628800

# %%
def luas_lingkaran(jari_jari):
  luas = 3.14 * jari_jari**2
  return luas
def luas_persegi(sisi):
  luas = sisi * sisi
  return luas
def luas_segitiga(alas, tinggi):
  luas = 0.5 * alas * tinggi
  return luas
while True:
  print("pilihan bangun datar yang akan dihitung luasnya")
  print("1. Lingkaran")
  print("2. Persegi")
  print("3. Segitiga")
  print("4. selesai")
  pilihan = input("Masukkan piliha anda(1/2/3/4); ")

  if pilihan == '1':
    jari_jari = float(input('Masukkan jari-jari lingkaran: '))
    luas = luas_lingkaran(jari_jari)
    print("luas lingkaran adalah:", luas)
  elif pilihan == '2':
    sisi = float(input('Masukkan sisi persegi: '))
    luas = luas_persegi(sisi)
    print("luas persegi adalah:", luas)
  elif pilihan == '3':
    alas = float(input('Masukkan alas segitiga: '))
    tinggi = float(input('Masukkan tinggi segitiga: '))
    luas = luas_segitiga(alas, tinggi)
    print("luas segitiga adalah:", luas)
  elif pilihan == '4':
    print("Terimakasih")
    break
  else:
    print("pilihan tidak valid. silakan coba lagi.")
# Out:
# pilihan bangun datar yang akan dihitung luasnya
# 1. Lingkaran
# 2. Persegi
# 3. Segitiga
# 4. selesai
# Masukkan piliha anda(1/2/3/4); 1
# Masukkan jari-jari lingkaran: 7
# luas lingkaran adalah: 153.86
# pilihan bangun datar yang akan dihitung luasnya
# 1. Lingkaran
# 2. Persegi
# 3. Segitiga
# 4. selesai
# Masukkan piliha anda(1/2/3/4); 2
# Masukkan sisi persegi: 2
# luas persegi adalah: 4.0
# pilihan bangun datar yang akan dihitung luasnya
# 1. Lingkaran
# 2. Persegi
# 3. Segitiga
# 4. selesai
# Masukkan piliha anda(1/2/3/4); 3
# Masukkan alas segitiga: 5
# Masukkan tinggi segitiga: 12
# luas segitiga adalah: 30.0
# pilihan bangun datar yang akan dihitung luasnya
# 1. Lingkaran
# 2. Persegi
# 3. Segitiga
# 4. selesai
# Masukkan piliha anda(1/2/3/4); 4
# Terimakasih
