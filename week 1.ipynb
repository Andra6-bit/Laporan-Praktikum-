# %%
print('Nama         : Muhammad Andra Firdaus')
print('NPM          : 2440506053')
print('Alamat       : Jl. Tentara pelajar,Magelang, Jawa tengah')
print('Tinggi badan : 175.5')
print('Berat Badan  : 60.0')
# Out:
# Nama         : Muhammad Andra Firdaus
# NPM          : 2440506053
# Alamat       : Jl. Tentara pelajar,Magelang, Jawa tengah
# Tinggi badan : 175.5
# Berat Badan  : 60.0

# %%
print('\033[1mUNIVERSITAS TIDAR\033[')
print('Universitas Tidar merupakan perguruan tinggi pemerintah atau perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.', end="\n\n")
print('\033[1mTEKNIK ELEKTRO\033[')
print('Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:')
print(' 1. S1 Teknik Elektro \033[3m(Bachelor of Electrical Engineering)\033[')
print(' 2. S1 Teknologi Informasi \033[3m(Bachelor of Information Technology)\033[')
print(' 3. S1 Teknik Mekatronika \033[3m(Bachelor of Mechatronics Engineering)\033[')
# Out:
# UNIVERSITAS TIDAR[
# Universitas Tidar merupakan perguruan tinggi pemerintah atau perguruan Tinggi Negeri yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
#
# TEKNIK ELEKTRO[
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:
#  1. S1 Teknik Elektro (Bachelor of Electrical Engineering)[
#  2. S1 Teknologi Informasi (Bachelor of Information Technology)[
#  3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)[

# %%
print('Hello, python !')
# Out:
# Hello, python !
